# %%
import pandas as pd
import numpy as np


teams = pd.read_csv("nfl_teams.csv")
teams.head()
# Out:
#              team_name team_name_short team_id team_id_pfr team_conference  \
# 0    Arizona Cardinals       Cardinals     ARI         CRD             NFC
# 1    Phoenix Cardinals       Cardinals     ARI         CRD             NFC
# 2  St. Louis Cardinals       Cardinals     ARI         ARI             NFC
# 3      Atlanta Falcons         Falcons     ATL         ATL             NFC
# 4     Baltimore Ravens          Ravens     BAL         RAV             AFC
#
#   team_division team_conference_pre2002 team_division_pre2002
# 0      NFC West                     NFC              NFC West
# 1           NaN                     NFC              NFC East
# 2           NaN                     NFC              NFC East
# 3     NFC South                     NFC              NFC West
# 4     AFC North                     AFC           AFC Central

# %%
data = pd.read_json("stadiums_nfl.json")
state = []
team = []
division = []
for row in range(0, len(data)):
    state.append(data["fields"][row]["state"])
    team.append(data["fields"][row]["team"])
    division.append(data["fields"][row]["division"])
team.append(team[12].split("/")[1])
team[12] = team[12].split("/")[0]
state.append(state[12])
division.append(division[12])
team[4]= "Chicago Bears"
nfl_loc = pd.DataFrame({"Team_Name": team, "State": state})
nfl_loc
states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}
for ii in range(0, len(nfl_loc)):
    state = nfl_loc["State"][ii]
    if state in states.keys():
        nfl_loc["State"][ii] = states[state]
        
nfl_loc
# Out:
#                Team_Name           State
# 0    Philadelphia Eagles    Pennsylvania
# 1     San Diego Chargers      California
# 2      Carolina Panthers  North Carolina
# 3   Jacksonville Jaguars         Florida
# 4          Chicago Bears        Illinois
# 5   New England Patriots   Massachusetts
# 6          Buffalo Bills        New York
# 7   Tampa Bay Buccaneers         Florida
# 8       Seattle Seahawks      Washington
# 9      Minnesota Vikings       Minnesota
# 10       Atlanta Falcons         Georgia
# 11    Cincinnati Bengals            Ohio
# 12       New York Giants      New Jersey
# 13     Green Bay Packers       Wisconsin
# 14        Houston Texans           Texas
# 15        St. Louis Rams        Missouri
# 16      Baltimore Ravens        Maryland
# 17         Detroit Lions        Michigan
# 18        Miami Dolphins         Florida
# 19    Indianapolis Colts         Indiana
# 20     Arizona Cardinals         Arizona
# 21      Cleveland Browns            Ohio
# ...

# %%
scores = pd.read_csv("spreadspoke_scores.csv")
scores = pd.read_csv("spreadspoke_scores.csv")
lst_20 = scores.loc[scores["schedule_season"]> 1999]
lst_20 = lst_20.drop(["schedule_week", "schedule_playoff", "team_favorite_id", "spread_favorite", "over_under_line", "over_under_line", "stadium_neutral", "weather_temperature", "weather_wind_mph", "weather_humidity", "weather_detail" ], axis = 1)
lst_20.columns = ["Scheduled Date", "Schedule Season", "Home Team", "Home Score", "Away Score", "Away Team", "Stadium"]
lst_20 = lst_20.dropna()
lst_20
# Out:
#       Scheduled Date  Schedule Season             Home Team  Home Score  \
# 7354      09/03/2000             2000       Atlanta Falcons        36.0
# 7355      09/03/2000             2000         Buffalo Bills        16.0
# 7356      09/03/2000             2000      Cleveland Browns         7.0
# 7357      09/03/2000             2000        Dallas Cowboys        14.0
# 7358      09/03/2000             2000     Green Bay Packers        16.0
# ...              ...              ...                   ...         ...
# 12406     01/13/2019             2018  New England Patriots        41.0
# 12407     01/13/2019             2018    New Orleans Saints        20.0
# 12408     01/20/2019             2018    Kansas City Chiefs        31.0
# 12409     01/20/2019             2018    New Orleans Saints        23.0
# 12410     02/03/2019             2018      Los Angeles Rams         3.0
#
#        Away Score             Away Team                  Stadium
# ...

# %%
lst_20["Home Team"].nunique()
# Out:
# 34

# %%
team_list = list(teams["team_name"])
team_list
# Out:
# ['Arizona Cardinals',
#  'Phoenix Cardinals',
#  'St. Louis Cardinals',
#  'Atlanta Falcons',
#  'Baltimore Ravens',
#  'Buffalo Bills',
#  'Carolina Panthers',
#  'Chicago Bears',
#  'Cincinnati Bengals',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Denver Broncos',
#  'Detroit Lions',
#  'Green Bay Packers',
#  'Houston Texans',
#  'Baltimore Colts',
#  'Indianapolis Colts',
#  'Jacksonville Jaguars',
#  'Kansas City Chiefs',
#  'Los Angeles Chargers',
#  'San Diego Chargers',
#  'Los Angeles Rams',
#  'St. Louis Rams',
#  'Miami Dolphins',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'Boston Patriots',
#  'New Orleans Saints',
#  'New York Giants',
#  'New York Jets',
#  'Los Angeles Raiders',
#  'Oakland Raiders',
#  'Philadelphia Eagles',
#  'Pittsburgh Steelers',
#  'Seattle Seahawks',
#  'San Francisco 49ers',
#  'Tampa Bay Buccaneers',
#  'Houston Oilers',
#  'Tennessee Oilers',
#  'Tennessee Titans',
#  'Washington Redskins']

# %%
team_scores = {}
for team in team_list:
    team_scores[team] = {"win": 0, "loss": 0, "tie": 0, 'all_time': 0,
                        '2000': 0, '2001': 0, '2002': 0, '2003':0,
                        '2004': 0, '2005': 0, '2006': 0, '2007': 0,
                        '2008': 0, '2009': 0, '2010': 0, '2011': 0,
                        '2012': 0, '2013': 0, '2014': 0, '2015': 0,
                        '2016': 0, '2017': 0, '2018': 0}

# %%
team_scores
# Out:
# {'Arizona Cardinals': {'win': 0,
#   'loss': 0,
#   'tie': 0,
#   'all_time': 0,
#   '2000': 0,
#   '2001': 0,
#   '2002': 0,
#   '2003': 0,
#   '2004': 0,
#   '2005': 0,
#   '2006': 0,
#   '2007': 0,
#   '2008': 0,
#   '2009': 0,
#   '2010': 0,
#   '2011': 0,
#   '2012': 0,
#   '2013': 0,
#   '2014': 0,
#   '2015': 0,
#   '2016': 0,
#   '2017': 0,
#   '2018': 0},
#  'Phoenix Cardinals': {'win': 0,
#   'loss': 0,
#   'tie': 0,
#   'all_time': 0,
#   '2000': 0,
#   '2001': 0,
#   '2002': 0,
#   '2003': 0,
#   '2004': 0,
#   '2005': 0,
#   '2006': 0,
#   '2007': 0,
#   '2008': 0,
#   '2009': 0,
#   '2010': 0,
#   '2011': 0,
#   '2012': 0,
#   '2013': 0,
#   '2014': 0,
#   '2015': 0,
#   '2016': 0,
#   '2017': 0,
#   '2018': 0},
#  'St. Louis Cardinals': {'win': 0,
#   'loss': 0,
#   'tie': 0,
#   'all_time': 0,
#   '2000': 0,
#   '2001': 0,
#   '2002': 0,
#   '2003': 0,
#   '2004': 0,
#   '2005': 0,
#   '2006': 0,
#   '2007': 0,
#   '2008': 0,
#   '2009': 0,
#   '2010': 0,
# ...

# %%
# calculate all time win percentage
## still need to parse for yearly stats
for row in range(0,len(scores)):
    
    test_df = scores.iloc[row, :]
    
    home_team = test_df["team_home"]
    away_team = test_df["team_away"]
    
    home_score = test_df["score_home"]
    away_score = test_df["score_away"]
    
    # home team wins, increment win
    if home_score > away_score:
        team_scores[home_team]["win"] += 1
        team_scores[away_team]["loss"] += 1
    elif home_score < away_score:
        team_scores[home_team]["loss"] += 1
        team_scores[away_team]["win"] += 1
    else:
        team_scores[home_team]["tie"] += 1
        team_scores[away_team]["tie"] += 1
        
for key in team_scores:
    win = team_scores[key]["win"]
    loss = team_scores[key]["loss"]
    tie = team_scores[key]["tie"]
    
    win_pct = win / (win + loss + tie)
    win_pct = np.round(win_pct, decimals=3)
    
    team_scores[key]["all_time"] = win_pct

# %%
team_scores
# Out:
# {'Arizona Cardinals': {'win': 176,
#   'loss': 234,
#   'tie': 17,
#   'all_time': 0.412,
#   '2000': 0,
#   '2001': 0,
#   '2002': 0,
#   '2003': 0,
#   '2004': 0,
#   '2005': 0,
#   '2006': 0,
#   '2007': 0,
#   '2008': 0,
#   '2009': 0,
#   '2010': 0,
#   '2011': 0,
#   '2012': 0,
#   '2013': 0,
#   '2014': 0,
#   '2015': 0,
#   '2016': 0,
#   '2017': 0,
#   '2018': 0},
#  'Phoenix Cardinals': {'win': 32,
#   'loss': 64,
#   'tie': 0,
#   'all_time': 0.333,
#   '2000': 0,
#   '2001': 0,
#   '2002': 0,
#   '2003': 0,
#   '2004': 0,
#   '2005': 0,
#   '2006': 0,
#   '2007': 0,
#   '2008': 0,
#   '2009': 0,
#   '2010': 0,
#   '2011': 0,
#   '2012': 0,
#   '2013': 0,
#   '2014': 0,
#   '2015': 0,
#   '2016': 0,
#   '2017': 0,
#   '2018': 0},
#  'St. Louis Cardinals': {'win': 145,
#   'loss': 165,
#   'tie': 10,
#   'all_time': 0.453,
#   '2000': 0,
#   '2001': 0,
#   '2002': 0,
#   '2003': 0,
#   '2004': 0,
#   '2005': 0,
#   '2006': 0,
#   '2007': 0,
#   '2008': 0,
#   '2009': 0,
# ...

# %%
# calculate all time win percentage
## still need to parse for yearly stats
for year in range(2000,2019):
    
    # get alll data for one season
    test_df = scores.loc[ scores["schedule_season"] == year, :]
    test_df = test_df.reset_index()
    
    # reset win/loss/tie ratio
    for keys in team_scores:
        team_scores[keys]["win"] = 0
        team_scores[keys]["loss"] = 0
        team_scores[keys]["tie"] = 0
        
    # within season loop through all games
    for row in range(0, len(test_df)):
        
        # go row by row, for individual games
        year_df = test_df.iloc[row, :]
        

        home_team = year_df["team_home"]
        away_team = year_df["team_away"]

        home_score = year_df["score_home"]
        away_score = year_df["score_away"]

        # home team wins, increment win
        if home_score > away_score:
            team_scores[home_team]["win"] += 1
            team_scores[away_team]["loss"] += 1
        elif home_score < away_score:
            team_scores[home_team]["loss"] += 1
            team_scores[away_team]["win"] += 1
        else:
            team_scores[home_team]["tie"] += 1
            team_scores[away_team]["tie"] += 1
        
    for key in team_scores:
        win = team_scores[key]["win"]
        loss = team_scores[key]["loss"]
        tie = team_scores[key]["tie"]
        
        try:
            win_pct = win / (win + loss + tie)
            win_pct = np.round(win_pct, decimals=3)

            year_str = str(year)
            team_scores[key][year_str] = win_pct 
        except:
            year_str = str(year)
            team_scores[key][year_str] = float("Nan")

# %%
team_scores_df = pd.DataFrame(team_scores).transpose()
team_scores_df = team_scores_df.drop(columns=["loss", "tie", "win", "all_time"])

# %%
team_scores_df.head()
# Out:
#                       2000   2001   2002   2003   2004   2005   2006   2007  \
# Arizona Cardinals    0.188  0.438  0.312  0.250  0.375  0.312  0.312  0.500
# Phoenix Cardinals      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# St. Louis Cardinals    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Atlanta Falcons      0.250  0.438  0.556  0.312  0.667  0.500  0.438  0.250
# Baltimore Ravens     0.800  0.611  0.438  0.588  0.562  0.375  0.765  0.312
#
#                       2008   2009   2010   2011   2012   2013   2014   2015  \
# Arizona Cardinals    0.600  0.611  0.312  0.500  0.312  0.625  0.647  0.778
# Phoenix Cardinals      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# St. Louis Cardinals    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Atlanta Falcons      0.647  0.562  0.765  0.588  0.778  0.250  0.375  0.500
# Baltimore Ravens     0.684  0.556  0.722  0.722  0.700  0.500  0.611  0.312
#
#                       2016   2017   2018
# ...

# %%
team_scores_df
# Out:
#                        2000   2001   2002   2003   2004   2005   2006   2007  \
# Arizona Cardinals     0.188  0.438  0.312  0.250  0.375  0.312  0.312  0.500
# Phoenix Cardinals       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# St. Louis Cardinals     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Atlanta Falcons       0.250  0.438  0.556  0.312  0.667  0.500  0.438  0.250
# Baltimore Ravens      0.800  0.611  0.438  0.588  0.562  0.375  0.765  0.312
# Buffalo Bills         0.500  0.188  0.500  0.375  0.562  0.312  0.438  0.438
# Carolina Panthers     0.438  0.062  0.438  0.700  0.438  0.684  0.500  0.438
# Chicago Bears         0.312  0.765  0.250  0.438  0.312  0.647  0.789  0.438
# Cincinnati Bengals    0.250  0.375  0.125  0.500  0.500  0.647  0.500  0.438
# Cleveland Browns      0.188  0.438  0.529  0.312  0.250  0.375  0.250  0.625
# Dallas Cowboys        0.312  0.312  0.312  0.588  0.375  0.562  0.529  0.765
# ...

# %%
team_scores_df
# drop nas for whole row - done
# merge rams and chargers
# replace nas as zero if partial row


team_scores_df = team_scores_df.dropna(how='all', axis=0)


team_scores_df = team_scores_df.rename({"Los Angeles Chargers": "LA/SD Chargers",
                                         "San Diego Chargers": "LA/SD Chargers", 
                                         "Los Angeles Rams": "LA/SL Rams", 
                                         "St. Louis Rams": "LA/SL Rams"})

team_scores_df = team_scores_df.reset_index()

team_scores_df = team_scores_df.fillna(0)


team_scores_df
# Out:
#                    index   2000   2001   2002   2003   2004   2005   2006  \
# 0      Arizona Cardinals  0.188  0.438  0.312  0.250  0.375  0.312  0.312
# 1        Atlanta Falcons  0.250  0.438  0.556  0.312  0.667  0.500  0.438
# 2       Baltimore Ravens  0.800  0.611  0.438  0.588  0.562  0.375  0.765
# 3          Buffalo Bills  0.500  0.188  0.500  0.375  0.562  0.312  0.438
# 4      Carolina Panthers  0.438  0.062  0.438  0.700  0.438  0.684  0.500
# 5          Chicago Bears  0.312  0.765  0.250  0.438  0.312  0.647  0.789
# 6     Cincinnati Bengals  0.250  0.375  0.125  0.500  0.500  0.647  0.500
# 7       Cleveland Browns  0.188  0.438  0.529  0.312  0.250  0.375  0.250
# 8         Dallas Cowboys  0.312  0.312  0.312  0.588  0.375  0.562  0.529
# 9         Denver Broncos  0.647  0.500  0.562  0.588  0.588  0.778  0.562
# 10         Detroit Lions  0.562  0.125  0.188  0.312  0.375  0.312  0.188
# 11     Green Bay Packers  0.562  0.722  0.706  0.611  0.588  0.250  0.500
# ...

# %%
team_scores_df.columns = ['Team_Name', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
       '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
       '2017', '2018']
team_scores_df = team_scores_df.groupby("Team_Name").mean()

team_scores_df
# Out:
#                        2000   2001   2002   2003   2004    2005   2006   2007  \
# Team_Name
# Arizona Cardinals     0.188  0.438  0.312  0.250  0.375  0.3120  0.312  0.500
# Atlanta Falcons       0.250  0.438  0.556  0.312  0.667  0.5000  0.438  0.250
# Baltimore Ravens      0.800  0.611  0.438  0.588  0.562  0.3750  0.765  0.312
# Buffalo Bills         0.500  0.188  0.500  0.375  0.562  0.3120  0.438  0.438
# Carolina Panthers     0.438  0.062  0.438  0.700  0.438  0.6840  0.500  0.438
# Chicago Bears         0.312  0.765  0.250  0.438  0.312  0.6470  0.789  0.438
# Cincinnati Bengals    0.250  0.375  0.125  0.500  0.500  0.6470  0.500  0.438
# Cleveland Browns      0.188  0.438  0.529  0.312  0.250  0.3750  0.250  0.625
# Dallas Cowboys        0.312  0.312  0.312  0.588  0.375  0.5620  0.529  0.765
# Denver Broncos        0.647  0.500  0.562  0.588  0.588  0.7780  0.562  0.438
# Detroit Lions         0.562  0.125  0.188  0.312  0.375  0.3120  0.188  0.438
# ...

# %%
team_scores_df["20_Yr_Avg"] = team_scores_df.mean(axis=1)
merged_nfl.columns = ['Team_Name', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
       '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
       '2016', '2017', '2018', '20_Yr_Avg', 'US_State']
merged_nfl = team_scores_df.merge(nfl_loc, left_on = "Team_Name", right_on = "Team_Name")

merged_nfl.to_csv('nfl_final.csv')
merged_nfl
# Out:
#                Team_Name   2000   2001   2002   2003   2004   2005   2006  \
# 0      Arizona Cardinals  0.188  0.438  0.312  0.250  0.375  0.312  0.312
# 1        Atlanta Falcons  0.250  0.438  0.556  0.312  0.667  0.500  0.438
# 2       Baltimore Ravens  0.800  0.611  0.438  0.588  0.562  0.375  0.765
# 3          Buffalo Bills  0.500  0.188  0.500  0.375  0.562  0.312  0.438
# 4      Carolina Panthers  0.438  0.062  0.438  0.700  0.438  0.684  0.500
# 5          Chicago Bears  0.312  0.765  0.250  0.438  0.312  0.647  0.789
# 6     Cincinnati Bengals  0.250  0.375  0.125  0.500  0.500  0.647  0.500
# 7       Cleveland Browns  0.188  0.438  0.529  0.312  0.250  0.375  0.250
# 8         Dallas Cowboys  0.312  0.312  0.312  0.588  0.375  0.562  0.529
# 9         Denver Broncos  0.647  0.500  0.562  0.588  0.588  0.778  0.562
# 10         Detroit Lions  0.562  0.125  0.188  0.312  0.375  0.312  0.188
# 11     Green Bay Packers  0.562  0.722  0.706  0.611  0.588  0.250  0.500
# ...

# %%
from bs4 import BeautifulSoup
import requests
import json
import pandas as pd
import matplotlib as plt

years = []
for x in range(20):
    years.append(2000 + x)

url = "https://www.basketball-reference.com/friv/standings.fcgi?month=2&day=13&year=1992&lg_id=NBA"

stats = {}
for year in years:
    stats[year] = {
        "stats": pd.read_html(f"https://www.basketball-reference.com/friv/standings.fcgi?month=2&day=13&year={year}&lg_id=NBA")
    }

for year in years:
    stats[year]["stats"][0] = stats[year]["stats"][0].rename(columns={"Eastern Conference":"Team Name"})
    stats[year]["stats"][1] = stats[year]["stats"][1].rename(columns={"Western Conference":"Team Name"})

data = {}
for year in years:
    data[year] = {
        'w/l' : stats[year]["stats"][0][['Team Name','W/L%']].dropna(),
        'w/l1' : stats[year]["stats"][1][['Team Name','W/L%']].dropna()
    }
win_pct = {}
for year in years:
    win_pct[year] = {
        'all': pd.concat([data[year]['w/l'],data[year]['w/l1']])
    }
for year in years:
    win_pct[year]['all']['Team Name'] = win_pct[year]['all']["Team Name"].apply(lambda x: x.replace('*', ''))

data2 = pd.merge(win_pct[2000]['all'], win_pct[2001]['all'], on='Team Name', how="outer")
data2 = pd.merge(data2, win_pct[2002]['all'], on='Team Name', how="outer")
data2 = pd.merge(data2, win_pct[2003]['all'], on='Team Name', how="outer")
data2 = pd.merge(data2, win_pct[2004]['all'], on='Team Name', how="outer")
data2 = pd.merge(data2, win_pct[2005]['all'], on='Team Name', how="outer")
data2 = pd.merge(data2, win_pct[2006]['all'], on='Team Name', how="outer")
data2 = pd.merge(data2, win_pct[2007]['all'], on='Team Name', how="outer")
data2 = pd.merge(data2, win_pct[2008]['all'], on='Team Name', how="outer")
data2 = pd.merge(data2, win_pct[2009]['all'], on='Team Name', how="outer")

data2.columns = ['Team Name', '2000', '2001', '2002', '2003',
       '2004', '2005', '2006', '2007', '2008', '2009']
    
data3 = pd.merge(win_pct[2010]['all'], win_pct[2011]['all'], on='Team Name', how="outer")
data3 = pd.merge(data3, win_pct[2012]['all'], on='Team Name', how="outer")
data3 = pd.merge(data3, win_pct[2013]['all'], on='Team Name', how="outer")
data3 = pd.merge(data3, win_pct[2014]['all'], on='Team Name', how="outer")
data3 = pd.merge(data3, win_pct[2015]['all'], on='Team Name', how="outer")
data3 = pd.merge(data3, win_pct[2016]['all'], on='Team Name', how="outer")
data3 = pd.merge(data3, win_pct[2017]['all'], on='Team Name', how="outer")
data3 = pd.merge(data3, win_pct[2018]['all'], on='Team Name', how="outer")


data3.columns = ['Team Name', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018']

full = pd.merge(data2, data3, on='Team Name', how="outer")

full_data = full.replace({"New Jersey Nets": "Brooklyn/NJ Nets","Brooklyn Nets": "Brooklyn/NJ Nets", "New Orleans Hornets": "New Orleans Hornets/Pelicans", "New Orleans Pelicans": "New Orleans Hornets/Pelicans", "New Orleans/Oklahoma City Hornets":"New Orleans Hornets/Pelicans", "Charlotte Bobcats":"Charlotte Hornets/Bobcats", "Charlotte Hornets":"Charlotte Hornets/Bobcats", "Memphis Grizzlies": "Memphis Grizzlies", "Vancouver Grizzlies": "Memphis Grizzlies", "Seattle SuperSonics":"Oklahoma City Thunder(SS)", "Oklahoma City Thunder": "Oklahoma City Thunder(SS)"})

full_data = full_data.groupby("Team Name").mean().reset_index()
full_data['20_Yr_Avg'] = full_data.mean(axis=1).round(3)

url = "https://geojango.com/pages/list-of-nba-teams"
data = pd.read_html(url)
nba_info = pd.DataFrame(data[0])
nba_states = [i.split(',', 1)[1] for i in nba_info['Arena Location']]
nba_states[-1] = 'Washington, D.C'

full_data['State'] = nba_states

# %%
full_data.columns = ['Team_Name', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
       '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
       '2016', '2017', '2018', '20_Yr_Avg', 'US_State']
full_data.to_csv(r'nba.csv')

# %%
full_data.columns
# Out:
# Index(['Team_Name', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '20_Yr_Avg', 'State'],
#       dtype='object')
